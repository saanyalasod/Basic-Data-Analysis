# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(9,5)

# %%
happy= pd.read_csv("world-happiness-report.csv")
happy.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
happy_2021= pd.read_csv("world-happiness-report-2021.csv")
happy_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
life_expectancy=happy_2021.groupby('Country name')[['Healthy life expectancy']].mean().sort_values('Healthy life expectancy', ascending=False)
life_expectancy
# Out:
#                            Healthy life expectancy
# Country name
# Singapore                                   76.953
# Hong Kong S.A.R. of China                   76.820
# Japan                                       75.100
# Spain                                       74.700
# Switzerland                                 74.400
# ...                                            ...
# Swaziland                                   50.833
# Ivory Coast                                 50.114
# Nigeria                                     50.102
# Lesotho                                     48.700
# Chad                                        48.478
#
# [149 rows x 1 columns]

# %%
life_expectancy1=life_expectancy.head(10).squeeze()
plt.xticks(rotation= 75)
sns.barplot(x=life_expectancy1.index, y=life_expectancy1);

# %%
df1=df.tail(10).squeeze()
plt.xticks(rotation= 75)
sns.barplot(x=df1.index, y=df1);

# %%
other=happy[(happy['Country name']=="India")]
other=other.groupby('year')[['Healthy life expectancy at birth']].mean()
other
# Out:
#       Healthy life expectancy at birth
# year
# 2006                             55.72
# 2007                             56.14
# 2008                             56.56
# 2009                             56.98
# 2010                             57.40
# 2011                             57.70
# 2012                             58.00
# 2013                             58.30
# 2014                             58.60
# 2015                             58.90
# 2016                             59.30
# 2017                             59.70
# 2018                             60.10
# 2019                             60.50
# 2020                             60.90

# %%
other.plot();

# %%
other=happy[(happy['Country name']=="India")]
other=other.groupby('year')[['Perceptions of corruption']].mean()
other
# Out:
#       Perceptions of corruption
# year
# 2006                      0.855
# 2007                      0.862
# 2008                      0.891
# 2009                      0.895
# 2010                      0.863
# 2011                      0.908
# 2012                      0.830
# 2013                      0.832
# 2014                      0.832
# 2015                      0.776
# 2016                      0.765
# 2017                      0.781
# 2018                      0.805
# 2019                      0.752
# 2020                      0.780

# %%
other.plot();

# %%
df=happy_2021.groupby('Regional indicator')[['Perceptions of corruption']].mean().sort_values('Perceptions of corruption', ascending=False)
df
# Out:
#                                     Perceptions of corruption
# Regional indicator
# Central and Eastern Europe                           0.850529
# South Asia                                           0.797429
# Latin America and Caribbean                          0.792600
# Sub-Saharan Africa                                   0.765944
# Middle East and North Africa                         0.762235
# Commonwealth of Independent States                   0.725083
# Southeast Asia                                       0.709111
# East Asia                                            0.683333
# Western Europe                                       0.523095
# North America and ANZ                                0.449250

# %%
df1=df.squeeze()
sns.barplot(x=df1,y=df1.index);

# %%
df1=df.tail(10).squeeze()
plt.xticks(rotation= 75)
sns.barplot(x=df1.index, y=df1);

# %%
happy_2021['Regional indicator'].unique()
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
other=happy_2021[(happy_2021['Regional indicator']=="South Asia")]
other
# Out:
#     Country name Regional indicator  Ladder score  \
# 86         Nepal         South Asia         5.269
# 88      Maldives         South Asia         5.198
# 100   Bangladesh         South Asia         5.025
# 104     Pakistan         South Asia         4.934
# 128    Sri Lanka         South Asia         4.325
# 138        India         South Asia         3.819
# 148  Afghanistan         South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 86                            0.070         5.406         5.132
# 88                            0.072         5.339         5.057
# 100                           0.046         5.115         4.934
# 104                           0.068         5.066         4.802
# 128                           0.066         4.454         4.196
# 138                           0.026         3.869         3.769
# 148                           0.038         2.596         2.449
#
# ...

# %%
sns.barplot(x=other['Country name'], y=other['Logged GDP per capita']);
