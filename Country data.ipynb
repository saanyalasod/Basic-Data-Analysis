# %%
import pandas as pd

# %%
df=pd.read_csv("countries.csv")
df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
len(df['location'].unique())
# Out:
# 210

# %%
l=df['continent'].unique()
l=list(l)
l
# Out:
# ['Asia', 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %%
df['population'].sum()
# Out:
# 7757980095.0

# %%
a= df.sort_values('population', ascending=False)
a.head(10)
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %%
df['overall_GDP_per_country']=df.population * df.gdp_per_capita
df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  overall_GDP_per_country
# 0                          0.50        1803.987             7.022622e+10
# 1                          2.89       11803.431             3.396791e+10
# ...

# %%
b = df.groupby('continent')['location'].count()
b
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %%
c = df.groupby('continent')['population'].sum()
c
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
d= df.sort_values('gdp_per_capita')
d=d[d.population > 100000000]
d.head(10)
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita  overall_GDP_per_country
# 63                         0.30        1729.927             1.988786e+11
# 15                         0.80        3523.984             5.803628e+11
# ...

# %%
(df.life_expectancy * df.population).sum()/df.population.sum()
# Out:
# 72.72165193409664

# %%
df1= pd.read_csv("results.csv")
df1
# Out:
#            date  new_cases  new_deaths  total_deaths  new_tests  total_cases  \
# 0    2019-12-31        0.0         0.0           0.0        NaN          0.0
# 1    2020-01-01        0.0         0.0           0.0        NaN          0.0
# 2    2020-01-02        0.0         0.0           0.0        NaN          0.0
# 3    2020-01-03        0.0         0.0           0.0        NaN          0.0
# 4    2020-01-04        0.0         0.0           0.0        NaN          0.0
# ..          ...        ...         ...           ...        ...          ...
# 243  2020-08-30     1444.0         1.0       35473.0    53541.0     267149.0
# 244  2020-08-31     1365.0         4.0       35477.0    42583.0     268514.0
# 245  2020-09-01      996.0         6.0       35483.0    54395.0     269510.0
# 246  2020-09-02      975.0         8.0       35491.0        NaN     270485.0
# 247  2020-09-03     1326.0         6.0       35497.0        NaN     271811.0
#
#      total_tests  cases_per_million
# ...

# %%
import random
df['new_deaths'] = random.randint(0,9)
df
# Out:
#                          location continent  population  life_expectancy  \
# 0                      Bangladesh      Asia  38928341.0            64.83
# 1    United States Virgin Islands    Europe   2877800.0            78.57
# 2                         Andorra    Africa  43851043.0            76.88
# 3                            Iran    Europe     77265.0            83.73
# 4                            Chad    Africa  32866268.0            61.15
# ..                            ...       ...         ...              ...
# 205                        France      Asia  97338583.0            75.40
# 206                    Madagascar    Africa    597330.0            70.26
# 207                     Sri Lanka      Asia  29825968.0            66.12
# 208                         China    Africa  18383956.0            63.89
# 209                  Saudi Arabia    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  overall_GDP_per_country  \
# ...

# %%
merge=df.merge(df1, on="new_deaths")
merge
# Out:
#           location continent  population  life_expectancy  \
# 0       Bangladesh      Asia  38928341.0            64.83
# 1       Bangladesh      Asia  38928341.0            64.83
# 2       Bangladesh      Asia  38928341.0            64.83
# 3       Bangladesh      Asia  38928341.0            64.83
# 4       Bangladesh      Asia  38928341.0            64.83
# ...            ...       ...         ...              ...
# 1885  Saudi Arabia    Africa  14862927.0            61.49
# 1886  Saudi Arabia    Africa  14862927.0            61.49
# 1887  Saudi Arabia    Africa  14862927.0            61.49
# 1888  Saudi Arabia    Africa  14862927.0            61.49
# 1889  Saudi Arabia    Africa  14862927.0            61.49
#
#       hospital_beds_per_thousand  gdp_per_capita  overall_GDP_per_country  \
# 0                            0.5        1803.987             7.022622e+10
# 1                            0.5        1803.987             7.022622e+10
# ...

# %%
merge.total_tests.isna().sum()
# Out:
# 420
